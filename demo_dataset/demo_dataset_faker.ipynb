# %%
import re
import inspect
import json
from enum import Enum

from faker import Faker
from faker.providers import DynamicProvider

import demo_dataset.types.common as common
import demo_dataset.types.smart_hubs as smart_hubs
import demo_dataset.types.smart_switches as smart_switches
import demo_dataset.types.smart_bulbs as smart_bulbs
import demo_dataset.types.smart_thermostat as smart_thermostat
import demo_dataset.types.vacuum_robots as vacuum_robots
import demo_dataset.types.solar_panels as solar_panels

modules = [
    common,
    smart_bulbs,
    smart_hubs,
    smart_switches,
    smart_thermostat,
    vacuum_robots,
    solar_panels,
]

fake = Faker()

# %%
# Helper Function to transform camel case to sake case
def camel_to_snake(camel_str: str):
    snake_str = re.sub(r'([a-z0-9])([A-Z])', r'\1_\2', camel_str)
    return snake_str.lower()

# %%
providers = []
for module in modules:
    providers.extend([
        DynamicProvider(
            provider_name=f"smarthome_{module.__name__.split('.')[-1]}_{camel_to_snake(name)}",
            elements=list(map(lambda e: e.value, obj))
        ) for name, obj in inspect.getmembers(module) 
            if (
                inspect.isclass(obj) and
                issubclass(obj, Enum) and
                obj is not Enum 
                and obj.__module__ == module.__name__
            )
    ])


print(providers)
for provider in providers:
    fake.add_provider(provider)
# Out:
# [<faker.providers.DynamicProvider object at 0x7f9c6b411240>, <faker.providers.DynamicProvider object at 0x7f9c6b49eb00>, <faker.providers.DynamicProvider object at 0x7f9c6b49ea10>, <faker.providers.DynamicProvider object at 0x7f9c6b49ead0>, <faker.providers.DynamicProvider object at 0x7f9c6b49e7d0>, <faker.providers.DynamicProvider object at 0x7f9c6b49c820>, <faker.providers.DynamicProvider object at 0x7f9c6b49c970>, <faker.providers.DynamicProvider object at 0x7f9c6b49ca30>, <faker.providers.DynamicProvider object at 0x7f9c6b49c400>, <faker.providers.DynamicProvider object at 0x7f9c6b49c460>, <faker.providers.DynamicProvider object at 0x7f9c6b49c040>, <faker.providers.DynamicProvider object at 0x7f9c6b49d840>, <faker.providers.DynamicProvider object at 0x7f9c6b49cdf0>, <faker.providers.DynamicProvider object at 0x7f9c6b49c1f0>, <faker.providers.DynamicProvider object at 0x7f9c6b49c220>, <faker.providers.DynamicProvider object at 0x7f9c6b49c1c0>, <faker.providers.DynamicProvider object at 0x7f9c6b49d9c0>, <faker.providers.DynamicProvider object at 0x7f9c6b49ebc0>, <faker.providers.DynamicProvider object at 0x7f9c6b49d090>, <faker.providers.DynamicProvider object at 0x7f9c6b49ec20>, <faker.providers.DynamicProvider object at 0x7f9c6b49e830>, <faker.providers.DynamicProvider object at 0x7f9c6b49ea40>, <faker.providers.DynamicProvider object at 0x7f9c6b49e650>, <faker.providers.DynamicProvider object at 0x7f9c6b49cd60>]

# %%
fake.smarthome_solar_panels_panel_height()
# Out:
# 1200

# %%
from dataclasses import dataclass
import random
from typing import List, Optional

from demo_dataset.types.common import Color, CommunicationProtocol, EnergyEfficiencyClass, Platform, Shape
from demo_dataset.types.smart_bulbs import BulbFeatures, LightColor, RequiresHub, Socket
from demo_dataset.types.smart_hubs import HubFeatures
from demo_dataset.types.smart_switches import SwitchFeatures, SwitchStyle
from demo_dataset.types.smart_thermostat import CWire, RemoteTemperatureSensor, ReplaceableBatteries, ThermostatFeatures
from demo_dataset.types.solar_panels import SolarBrand, PanelLength, PanelHeight, PanelWidth
from demo_dataset.types.vacuum_robots import Dock, HardwareFeature, SoftwareFeature


@dataclass(kw_only=True, init=False)
class SmartProduct:
    # 10 long numeric string beginning with 11xxxxxxxx
    product_no: Optional[str] = None
    product_type: str
    name: Optional[str] = None
    brand: str
    price: float
    description: Optional[str] = None


@dataclass(kw_only=True)
class SmartSwitch(SmartProduct):
    platforms: List[Platform]
    communication_protocol: List[CommunicationProtocol]
    style: SwitchStyle
    features: SwitchFeatures

    def __init__(self):
        self.brand = fake.smarthome_common_brand()
        self.product_type = self.__class__.__name__
        self.price = random.choice([22.99, 29.99, 15.00, 50.00])
        self.platforms = list({fake.smarthome_common_platform() for _ in range(fake.random_int(3, 9))})
        self.communication_protocol = list({fake.smarthome_common_communication_protocol() for _ in range(fake.random_int(3, 6))})
        self.style = fake.smarthome_smart_switches_switch_style()
        self.features = list({fake.smarthome_smart_switches_switch_features() for _ in range(fake.random_int(3, 8))})


@dataclass(kw_only=True)
class SmartBulb(SmartProduct):
    platforms: List[Platform]
    communication_protocol: List[CommunicationProtocol]
    light_color: LightColor
    socket: Socket
    energy_efficiency_class: EnergyEfficiencyClass
    features: BulbFeatures
    requireshub: RequiresHub
    lifetime: int
    wattage: int
    brightness: int
    color_temp: int | None

    def __init__(self):
        self.brand = fake.smarthome_common_brand()
        self.product_type = self.__class__.__name__
        self.price = random.choice([22.99, 29.99, 8.00, 13.99, 18.99, 9.99, 28.99])
        self.platforms = list({fake.smarthome_common_platform() for _ in range(fake.random_int(3, 9))})
        self.communication_protocol = list({fake.smarthome_common_communication_protocol() for _ in range(fake.random_int(3, 6))})
        self.light_color = fake.smarthome_smart_bulbs_light_color()
        self.socket = fake.smarthome_smart_bulbs_socket()
        self.energy_efficiency_class = fake.smarthome_common_energy_efficiency_class()
        self.features = fake.smarthome_smart_bulbs_bulb_features()
        self.requireshub = fake.smarthome_smart_bulbs_requires_hub()
        self.lifetime = random.choice([10000, 15000, 20000, 25000, 30000])
        self.wattage = random.choice([6, 8, 10, 12,  60])
        self.brightness = random.choice([500, 600, 800, 900])
        self.color_temp = random.choice([2700, 3000, 4000, 6000]) if self.light_color != "RGB" else None


@dataclass(kw_only=True)
class SmartThermostat(SmartProduct):
    platforms: List[Platform]
    communication_protocol: List[CommunicationProtocol]
    color: Color
    shape: Shape
    features: List[ThermostatFeatures]
    cwire: CWire
    remote_temperature_sensor: RemoteTemperatureSensor
    replaceable_batteries: ReplaceableBatteries

    def __init__(self):
        self.brand = fake.smarthome_common_brand()
        self.product_type = self.__class__.__name__
        self.platforms = list({fake.smarthome_common_platform() for _ in range(fake.random_int(3, 9))})
        self.price = random.choice([100.00, 133.99, 250.00, 95.00, 99.99, 80.00, 75.00, 175.99])
        self.communication_protocol = list({fake.smarthome_common_communication_protocol() for _ in range(fake.random_int(3, 6))})
        self.color = fake.smarthome_common_color()
        self.shape = fake.smarthome_common_shape()
        self.features = list({fake.smarthome_smart_thermostat_thermostat_features() for _ in range(fake.random_int(3, 9))})
        self.cwire = fake.smarthome_smart_thermostat_cwire()
        self.remote_temperature_sensor = fake.smarthome_smart_thermostat_remote_temperature_sensor()
        self.replaceable_batteries = fake.smarthome_smart_thermostat_replaceable_batteries()


@dataclass(kw_only=True)
class SmartHub(SmartProduct):
    platforms: List[Platform]
    communication_protocol: List[CommunicationProtocol]
    features: List[HubFeatures]

    def __init__(self):
        self.brand = fake.smarthome_common_brand()
        self.product_type = self.__class__.__name__
        self.price = random.choice([55.00, 100.00, 155.00, 230.00, 190.00])
        self.platforms = list({fake.smarthome_common_platform() for _ in range(fake.random_int(3, 9))})
        self.communication_protocol = list({fake.smarthome_common_communication_protocol() for _ in range(fake.random_int(3, 6))})
        self.features = list({fake.smarthome_smart_hubs_hub_features() for _ in range(fake.random_int(1, 2))})


@dataclass(kw_only=True)
class VacuumRobot(SmartProduct):
    suction_strength: int
    hardware_features: List[HardwareFeature]
    software_features: List[SoftwareFeature]
    dock: Dock

    def __init__(self):
        self.brand = fake.smarthome_common_brand()
        self.product_type = self.__class__.__name__
        self.price = random.choice([200.00, 300.00, 400.00, 500.00, 600.00, 1000.00])
        self.suction_strength = random.choice([5300, 6000, 2700, 2000, 3000])
        self.hardware_features = list({fake.smarthome_vacuum_robots_hardware_feature() for _ in range(fake.random_int(2, 5))})
        self.software_features = list({fake.smarthome_vacuum_robots_software_feature() for _ in range(fake.random_int(1, 3))})
        self.dock = fake.smarthome_vacuum_robots_dock()



@dataclass(kw_only=True, init=False)
class SolarPanel(SmartProduct):
    brand: SolarBrand
    length: PanelLength
    height: PanelHeight
    width: PanelWidth
    max_power_output: int
    weight: int

    def __init__(self):
        self.brand = fake.smarthome_solar_panels_solar_brand()
        self.product_type = self.__class__.__name__
        self.length = fake.smarthome_solar_panels_panel_length()
        self.height = fake.smarthome_solar_panels_panel_height()
        self.width = fake.smarthome_solar_panels_panel_width()
        self.surface_area = self.length * self.height / 1000000
        self.max_power_output = random.choice([100, 200, 300, 400, 450])
        self.price = round((self.max_power_output * 0.01 * self.surface_area * random.choice([60, 75, 85]) * 0.2), 2)
        self.weight = round((self.surface_area * fake.random_int(16, 24)), 2)

# %%
import dataclasses

products = []
products.extend([dataclasses.asdict(SmartSwitch()) for _ in range(10)])
products.extend([dataclasses.asdict(SmartBulb()) for _ in range(30)])
products.extend([dataclasses.asdict(SmartThermostat()) for _ in range(10)])
products.extend([dataclasses.asdict(SmartHub()) for _ in range(10)])
products.extend([dataclasses.asdict(VacuumRobot()) for _ in range(10)])
products.extend([dataclasses.asdict(SolarPanel()) for _ in range(10)])

products
# Out:
# [{'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 50.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'IFTTT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'SWITCH',
#   'features': ['THREE_WAY',
#    'MOTION_ACTIVATED',
#    'TWO_POLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['ALEXA', 'APPLE_HOME_KIT', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER'],
#   'style': 'DIMMER',
#   'features': ['NO_NEUTRAL_WIRE_NEEDED',
#    'MOTION_ACTIVATED',
#    'CEILING_FAN_SWITCH',
#    'THREE_POLE',
#    'TWO_POLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 50.0,
#   'description': None,
#   'platforms': ['MATTER', 'SMART_THINGS', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['NO_NEUTRAL_WIRE_NEEDED',
#    'THREE_POLE',
#    'LOCAL_ONLY_AVAILABLE',
#    'TWO_POLE',
#    'NEUTRAL_WIRE_NEEDED']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'SMART_THINGS', 'IFTTT', 'ALEXA'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'THREE_POLE',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'TWO_POLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'CEILING_FAN_SWITCH',
#    'THREE_POLE',
#    'LOCAL_ONLY_AVAILABLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'MATTER'],
#   'communication_protocol': ['MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'MOTION_ACTIVATED',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['ALEXA', 'MATTER', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'WIFI'],
#   'style': 'DIMMER',
#   'features': ['CEILING_FAN_SWITCH',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'TWO_POLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'MATTER',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE',
#    'MOTION_ACTIVATED']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 15.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'HUBITAT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'BLUETOOTH'],
#   'style': 'SWITCH',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'TWO_POLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 50.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'MATTER'],
#   'style': 'SWITCH',
#   'features': ['NEUTRAL_WIRE_NEEDED', 'NO_NEUTRAL_WIRE_NEEDED']},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'D',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 30000,
#   'wattage': 12,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'B',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 25000,
#   'wattage': 6,
#   'brightness': 900,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HOME_ASSISTANT', 'ALEXA', 'IFTTT'],
#   'communication_protocol': ['MATTER', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'G',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 15000,
#   'wattage': 12,
#   'brightness': 500,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'D',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 20000,
#   'wattage': 12,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'MATTER', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'D',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 60,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'F',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'HUBITAT',
#    'IFTTT',
#    'SMART_THINGS',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER'],
#   'light_color': 'RGB',
#   'socket': 'E14',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 20000,
#   'wattage': 10,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'SMART_THINGS',
#    'IFTTT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 25000,
#   'wattage': 6,
#   'brightness': 600,
#   'color_temp': 4000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'D',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 6,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E12',
#   'energy_efficiency_class': 'F',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 25000,
#   'wattage': 10,
#   'brightness': 600,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E27',
#   'energy_efficiency_class': 'C',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 10000,
#   'wattage': 12,
#   'brightness': 600,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['ALEXA', 'IFTTT', 'MATTER', 'SMART_THINGS'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'C',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 10,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'MATTER',
#    'SMART_THINGS',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 60,
#   'brightness': 800,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HOME_ASSISTANT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'MATTER', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'G',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 15000,
#   'wattage': 6,
#   'brightness': 800,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'IFTTT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E12',
#   'energy_efficiency_class': 'E',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 30000,
#   'wattage': 8,
#   'brightness': 800,
#   'color_temp': 6000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'HUBITAT',
#    'IFTTT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['MATTER', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'C',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 8,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['MATTER', 'SMART_THINGS', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E27',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 10000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'GOOGLE_HOME', 'MATTER'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'C',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 25000,
#   'wattage': 60,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 13.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'GOOGLE_HOME', 'MATTER'],
#   'communication_protocol': ['WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'A',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 8,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['IFTTT', 'GOOGLE_HOME', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD',
#    'Z_WAVE',
#    'WIFI',
#    'MATTER',
#    'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E40',
#   'energy_efficiency_class': 'E',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 10,
#   'brightness': 800,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'B',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 15000,
#   'wattage': 10,
#   'brightness': 800,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'MATTER', 'HUBITAT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'C',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 30000,
#   'wattage': 10,
#   'brightness': 900,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'IFTTT', 'SMART_THINGS', 'ALEXA'],
#   'communication_protocol': ['THREAD', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 25000,
#   'wattage': 8,
#   'brightness': 900,
#   'color_temp': 4000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E27',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 10000,
#   'wattage': 12,
#   'brightness': 800,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'ALEXA'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'MATTER'],
#   'light_color': 'RGB',
#   'socket': 'G9',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 25000,
#   'wattage': 8,
#   'brightness': 800,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'ALEXA'],
#   'communication_protocol': ['THREAD',
#    'Z_WAVE',
#    'WIFI',
#    'ZIGBEE',
#    'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E12',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 25000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': 6000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['GOOGLE_HOME', 'MATTER', 'SMART_THINGS', 'IFTTT'],
#   'communication_protocol': ['Z_WAVE',
#    'WIFI',
#    'ZIGBEE',
#    'MATTER',
#    'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'F',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 10000,
#   'wattage': 6,
#   'brightness': 900,
#   'color_temp': 6000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'ALEXA', 'MATTER', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'F',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 15000,
#   'wattage': 6,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'B',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 12,
#   'brightness': 600,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'MATTER',
#    'SMART_THINGS',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 30000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 75.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'color': 'BLUE',
#   'shape': 'CIRCLE',
#   'features': ['LOCAL_ONLY',
#    'AIR_QUALITY_SENSOR',
#    'PHYSICAL_BUTTONS',
#    'PHYSICAL_DIAL',
#    'USAGE_REPORTS'],
#   'cwire': 'ADAPTER_INCLUDED',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 80.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'HUBITAT'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'BLUE',
#   'shape': 'CIRCLE',
#   'features': ['AIR_QUALITY_SENSOR',
#    'TOUCH_SCREEN',
#    'USAGE_REPORTS',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X4'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 75.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'GOOGLE_HOME', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI'],
#   'color': 'BLACK',
#   'shape': 'RECTANGLE',
#   'features': ['LOCAL_ONLY'],
#   'cwire': 'ADAPTER_INCLUDED',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X2'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'GOOGLE_HOME', 'MATTER', 'SMART_THINGS'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'BLACK',
#   'shape': 'RECTANGLE',
#   'features': ['GEOFENCING',
#    'PHYSICAL_BUTTONS',
#    'LOCAL_ONLY',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'ADAPTER_INCLUDED',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 250.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'SILVER',
#   'shape': 'CIRCLE',
#   'features': ['LOCAL_ONLY',
#    'GEOFENCING',
#    'AIR_QUALITY_SENSOR',
#    'TOUCH_SCREEN',
#    'PHYSICAL_BUTTONS',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'HUBITAT'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'color': 'WHITE',
#   'shape': 'RECTANGLE',
#   'features': ['OPEN_API',
#    'TOUCH_SCREEN',
#    'USAGE_REPORTS',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'AVAILABLE_AS_ADD_ON',
#   'replaceable_batteries': 'AA_X4'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 250.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'BLUE',
#   'shape': 'RECTANGLE',
#   'features': ['AIR_QUALITY_SENSOR',
#    'PHYSICAL_BUTTONS',
#    'TOUCH_SCREEN',
#    'LOCAL_ONLY'],
#   'cwire': 'REQUIRES_C_WIRE_OR_ADAPTER',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 99.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'HUBITAT',
#    'IFTTT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD',
#    'Z_WAVE',
#    'WIFI',
#    'ZIGBEE',
#    'MATTER',
#    'BLUETOOTH'],
#   'color': 'SILVER',
#   'shape': 'OVAL',
#   'features': ['TOUCH_SCREEN', 'USAGE_REPORTS', 'ENERGY_SAVING_TIPS'],
#   'cwire': 'REQUIRES_C_WIRE_OR_ADAPTER',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X2'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 75.0,
#   'description': None,
#   'platforms': ['ALEXA', 'MATTER', 'IFTTT'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'color': 'SILVER',
#   'shape': 'RECTANGLE',
#   'features': ['AIR_QUALITY_SENSOR', 'TOUCH_SCREEN', 'LOCAL_ONLY'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AA_X2'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HOME_ASSISTANT', 'GOOGLE_HOME', 'IFTTT'],
#   'communication_protocol': ['WIFI', 'BLUETOOTH'],
#   'color': 'WHITE',
#   'shape': 'RECTANGLE',
#   'features': ['AIR_QUALITY_SENSOR',
#    'TOUCH_SCREEN',
#    'PHYSICAL_DIAL',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'REQUIRES_C_WIRE_OR_ADAPTER',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'HUBITAT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'WIFI'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 230.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'IFTTT',
#    'ALEXA'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'BLUETOOTH'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 55.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'BLUETOOTH'],
#   'features': ['SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 155.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'IFTTT', 'SMART_THINGS', 'ALEXA'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 155.0,
#   'description': None,
#   'platforms': ['ALEXA', 'APPLE_HOME_KIT', 'HUBITAT'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'WIFI'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 55.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'GOOGLE_HOME', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'ZIGBEE'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 190.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'HUBITAT', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 155.0,
#   'description': None,
#   'platforms': ['ALEXA', 'GOOGLE_HOME', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['Z_WAVE', 'BLUETOOTH'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 190.0,
#   'description': None,
#   'platforms': ['GOOGLE_HOME', 'MATTER', 'SMART_THINGS'],
#   'communication_protocol': ['Z_WAVE', 'BLUETOOTH'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'IFTTT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'MATTER', 'WIFI'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 600.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['LI_DAR',
#    'SELF_CLEANING_BRUSH_ROLL',
#    'MOP',
#    'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['LI_DAR', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 300.0,
#   'description': None,
#   'suction_strength': 3000,
#   'hardware_features': ['LI_DAR', 'MOP', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING', 'OBSTACLE_AVOIDANCE'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'Intuit Home',
#   'price': 300.0,
#   'description': None,
#   'suction_strength': 3000,
#   'hardware_features': ['MOP'],
#   'software_features': ['HOME_MAPPING',
#    'SPECIFY_CLEANING_ZONES',
#    'OBSTACLE_AVOIDANCE'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 3000,
#   'hardware_features': ['MOP', 'SIDE_BRUSHES', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING', 'SPECIFY_CLEANING_ZONES'],
#   'dock': 'DOCK_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'Hometics',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['MOP', 'SIDE_BRUSHES', 'SELF_CLEANING_BRUSH_ROLL'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'FerroSync',
#   'price': 500.0,
#   'description': None,
#   'suction_strength': 2000,
#   'hardware_features': ['LI_DAR', 'SIDE_BRUSHES', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'Orbital Home',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 5300,
#   'hardware_features': ['SIDE_BRUSHES'],
#   'software_features': ['OBSTACLE_AVOIDANCE'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 500.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['SELF_CLEANING_MOP',
#    'SIDE_BRUSHES',
#    'SELF_CLEANING_BRUSH_ROLL'],
#   'software_features': ['SPECIFY_CLEANING_ZONES', 'OBSTACLE_AVOIDANCE'],
#   'dock': 'DOCK_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': None,
#   'brand': 'CasaCore',
#   'price': 600.0,
#   'description': None,
#   'suction_strength': 5300,
#   'hardware_features': ['LI_DAR', 'MOP', 'SIDE_BRUSHES'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'Yellow Dwarf Power',
#   'price': 67.2,
#   'description': None,
#   'length': 1400,
#   'height': 1000,
#   'width': 30,
#   'max_power_output': 400,
#   'weight': 29.4},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'SolarTuitive',
#   'price': 67.2,
#   'description': None,
#   'length': 1400,
#   'height': 1000,
#   'width': 50,
#   'max_power_output': 400,
#   'weight': 28.0},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'SolarTuitive',
#   'price': 223.76,
#   'description': None,
#   'length': 1950,
#   'height': 1500,
#   'width': 50,
#   'max_power_output': 450,
#   'weight': 61.42},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'SolarTuitive',
#   'price': 24.48,
#   'description': None,
#   'length': 1700,
#   'height': 1200,
#   'width': 40,
#   'max_power_output': 100,
#   'weight': 46.92},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'Aurora Panel',
#   'price': 195.08,
#   'description': None,
#   'length': 1700,
#   'height': 1500,
#   'width': 40,
#   'max_power_output': 450,
#   'weight': 61.2},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'Yellow Dwarf Power',
#   'price': 105.3,
#   'description': None,
#   'length': 1950,
#   'height': 1500,
#   'width': 50,
#   'max_power_output': 300,
#   'weight': 64.35},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'SolarTuitive',
#   'price': 131.62,
#   'description': None,
#   'length': 1950,
#   'height': 1500,
#   'width': 50,
#   'max_power_output': 300,
#   'weight': 52.65},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'Yellow Dwarf Power',
#   'price': 138.72,
#   'description': None,
#   'length': 1700,
#   'height': 1200,
#   'width': 30,
#   'max_power_output': 400,
#   'weight': 34.68},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'Yellow Dwarf Power',
#   'price': 30.6,
#   'description': None,
#   'length': 1700,
#   'height': 1500,
#   'width': 30,
#   'max_power_output': 100,
#   'weight': 51.0},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': None,
#   'brand': 'Aurora Panel',
#   'price': 20.4,
#   'description': None,
#   'length': 1700,
#   'height': 1000,
#   'width': 50,
#   'max_power_output': 100,
#   'weight': 30.6}]

# %%
from langchain_ollama import OllamaLLM


llm = OllamaLLM(model="llama3.1:8b", temperature=0.8)

# %%
from langchain.prompts import PromptTemplate

prompt_template = PromptTemplate(
    input_variables=["json_data"],
    template="""
    Du bist ein KI-Modell für die generierung von Produkttiteln. Deine Aufgabe ist es auf Grundlage übergebener Werte einen Titel für ein Produkt zu erzeugen, der Titel soll kurz und knapp auf basis des gegebenen JSON Objects erstellt werden.
    Gebe nur den Titel des Produkts aus ohne weiteren Kommentar. Sei kreativ beim erstellen des Produkttitels, wie ein Name für eine Produktfamilie und einer Generation . Verwende auf keinen Fall die Brand im Titel. Verwende auf keinen Fall den Preis im Titel. Verwende auf keinen Fall den product_type im Titel. Verwende auf keinen Fall den product_no im Titel. Verwende auf keinen Fall den description im Titel. Gebe niemals mehrere Titel oder alternative Titel aus. Generiere immer nur genau einen prägnanten Titel.
    

    Basierend auf den folgenden Werten, schreibe einen Produkttitel:
    {json_data}
    """
)

chain = prompt_template | llm

for idx, product in enumerate(products):
    chunks = []
    for chunk in chain.stream({"json_data": json.dumps(product)}):
        chunks.append(chunk)
    products[idx]["name"] = "".join(chunks)

products
# Out:
# [{'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'IntelliSwitch Evolution',
#   'brand': 'Hometics',
#   'price': 50.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'IFTTT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'SWITCH',
#   'features': ['THREE_WAY',
#    'MOTION_ACTIVATED',
#    'TWO_POLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Intuit Home DIMMER 3.0 Smart',
#   'brand': 'Intuit Home',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['ALEXA', 'APPLE_HOME_KIT', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER'],
#   'style': 'DIMMER',
#   'features': ['NO_NEUTRAL_WIRE_NEEDED',
#    'MOTION_ACTIVATED',
#    'CEILING_FAN_SWITCH',
#    'THREE_POLE',
#    'TWO_POLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Intuit Smart DIMMER Generation 1',
#   'brand': 'Intuit Home',
#   'price': 50.0,
#   'description': None,
#   'platforms': ['MATTER', 'SMART_THINGS', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['NO_NEUTRAL_WIRE_NEEDED',
#    'THREE_POLE',
#    'LOCAL_ONLY_AVAILABLE',
#    'TWO_POLE',
#    'NEUTRAL_WIRE_NEEDED']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Intuit Home SmartDimmer Home Edition 1 - Generation 1',
#   'brand': 'Intuit Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'SMART_THINGS', 'IFTTT', 'ALEXA'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'THREE_POLE',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'TWO_POLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Intuit Home Smart DIMMER G1 Compatibel',
#   'brand': 'Intuit Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'CEILING_FAN_SWITCH',
#    'THREE_POLE',
#    'LOCAL_ONLY_AVAILABLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Hometics NeoSwitch',
#   'brand': 'Hometics',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'MATTER'],
#   'communication_protocol': ['MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'MOTION_ACTIVATED',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Orbital Home SmartSwitch GEN 2 Dimmer - Smart Lichtsteuerung für dein Zuhause',
#   'brand': 'Orbital Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['ALEXA', 'MATTER', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'WIFI'],
#   'style': 'DIMMER',
#   'features': ['CEILING_FAN_SWITCH',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'TWO_POLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'FerroSync G1 - Geniale Lichtsteuerung für dein Zuhause',
#   'brand': 'FerroSync',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'MATTER',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'style': 'DIMMER',
#   'features': ['THREE_WAY',
#    'NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE',
#    'MOTION_ACTIVATED']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'SmartSwitch Evolution X - Klassischer Stil neu definiert',
#   'brand': 'Hometics',
#   'price': 15.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'HUBITAT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'BLUETOOTH'],
#   'style': 'SWITCH',
#   'features': ['THREE_WAY',
#    'NO_NEUTRAL_WIRE_NEEDED',
#    'LOCAL_ONLY_AVAILABLE',
#    'NEUTRAL_WIRE_NEEDED',
#    'TWO_POLE']},
#  {'product_no': None,
#   'product_type': 'SmartSwitch',
#   'name': 'Intuit Connect - SmartTouch Generation 2',
#   'brand': 'Intuit Home',
#   'price': 50.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'MATTER'],
#   'style': 'SWITCH',
#   'features': ['NEUTRAL_WIRE_NEEDED', 'NO_NEUTRAL_WIRE_NEEDED']},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': '"Hometics Smart RGB LED E27 D-Klasse" \n\n Ich habe mich entschieden die Bestehende Bezeichnung zu verwenden. Dieser Titel ist kurz und prägnant und beschreibt das Produkt genau ohne auf eine bestimmte Marke hinzuweisen.',
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'D',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 30000,
#   'wattage': 12,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'CasaCore Gen2 Maximal Effizienz LED Leuchte',
#   'brand': 'CasaCore',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'B',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 25000,
#   'wattage': 6,
#   'brightness': 900,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Intuit Smart Lux E14 Weiß',
#   'brand': 'Intuit Home',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HOME_ASSISTANT', 'ALEXA', 'IFTTT'],
#   'communication_protocol': ['MATTER', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'G',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 15000,
#   'wattage': 12,
#   'brightness': 500,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'RGB Lichtspiel Master',
#   'brand': 'FerroSync',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'D',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 20000,
#   'wattage': 12,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Generation D - Hometics Edition',
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'MATTER', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'D',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 60,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Hometics SmartBulb Generation One - Weiß',
#   'brand': 'Hometics',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'F',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Intuit RGB Smart Licht - Generation 2 Efficacy Edition',
#   'brand': 'Intuit Home',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'HUBITAT',
#    'IFTTT',
#    'SMART_THINGS',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER'],
#   'light_color': 'RGB',
#   'socket': 'E14',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 20000,
#   'wattage': 10,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Motion Sensory E14 A++',
#   'brand': 'FerroSync',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'SMART_THINGS',
#    'IFTTT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 25000,
#   'wattage': 6,
#   'brightness': 600,
#   'color_temp': 4000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb CasaCore Core RGB Edition',
#   'brand': 'CasaCore',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'D',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 6,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartWave Hub E12',
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E12',
#   'energy_efficiency_class': 'F',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 25000,
#   'wattage': 10,
#   'brightness': 600,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Purezza CasaCore Smart Bulb Generation',
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E27',
#   'energy_efficiency_class': 'C',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 10000,
#   'wattage': 12,
#   'brightness': 600,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Evolution: Licht ohne Grenzen',
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['ALEXA', 'IFTTT', 'MATTER', 'SMART_THINGS'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'C',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 10,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'CasaCore SmartGenie A RGB Lichtschalter',
#   'brand': 'CasaCore',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'MATTER',
#    'SMART_THINGS',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 60,
#   'brightness': 800,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'CasaCore SmartBulb G: Licht, Anpassbar.',
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HOME_ASSISTANT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'MATTER', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'G',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 15000,
#   'wattage': 6,
#   'brightness': 800,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Orbital Motion E12 Bright White Edition',
#   'brand': 'Orbital Home',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'IFTTT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E12',
#   'energy_efficiency_class': 'E',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 30000,
#   'wattage': 8,
#   'brightness': 800,
#   'color_temp': 6000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Hometics RGB SmartBulb Gen.1',
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'HUBITAT',
#    'IFTTT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['MATTER', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'C',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 8,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartLife E27 Motion White Edition',
#   'brand': 'CasaCore',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['MATTER', 'SMART_THINGS', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E27',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 10000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartLicht Erfolg G2',
#   'brand': 'Orbital Home',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'GOOGLE_HOME', 'MATTER'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'C',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 25000,
#   'wattage': 60,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'RGB SmartBulb Generation 1 - Leuchtkraft ohne Grenzen',
#   'brand': 'Orbital Home',
#   'price': 13.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'GOOGLE_HOME', 'MATTER'],
#   'communication_protocol': ['WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E27',
#   'energy_efficiency_class': 'A',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 8,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartLicht 2.0 - Effizienz Plus',
#   'brand': 'Hometics',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['IFTTT', 'GOOGLE_HOME', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD',
#    'Z_WAVE',
#    'WIFI',
#    'MATTER',
#    'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E40',
#   'energy_efficiency_class': 'E',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 20000,
#   'wattage': 10,
#   'brightness': 800,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartLicht fÃ¼r CasaCore X: WeiÃf mit Effekten',
#   'brand': 'CasaCore',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'Z_WAVE'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'B',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 15000,
#   'wattage': 10,
#   'brightness': 800,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Hometics RGB E12 LED Lichteffekt',
#   'brand': 'Hometics',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'MATTER', 'HUBITAT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'WIFI'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'C',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 30000,
#   'wattage': 10,
#   'brightness': 900,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'WhiteWise G9 Smart Lichtsphäre mit Thread-Technologie',
#   'brand': 'Hometics',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'IFTTT', 'SMART_THINGS', 'ALEXA'],
#   'communication_protocol': ['THREAD', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'NO_HUB_REQUIRED',
#   'lifetime': 25000,
#   'wattage': 8,
#   'brightness': 900,
#   'color_temp': 4000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Pro: Energieeffizient mit LED-Technologie - Thread-Kompatibel',
#   'brand': 'FerroSync',
#   'price': 18.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'WIFI'],
#   'light_color': 'WHITE',
#   'socket': 'E27',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 10000,
#   'wattage': 12,
#   'brightness': 800,
#   'color_temp': 3000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Energieeffizienter Genie G9 - Pure Effizienz',
#   'brand': 'Orbital Home',
#   'price': 28.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'ALEXA'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'MATTER'],
#   'light_color': 'RGB',
#   'socket': 'G9',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 25000,
#   'wattage': 8,
#   'brightness': 800,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Pro E12 - Effektvoll weiß',
#   'brand': 'Orbital Home',
#   'price': 22.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'SMART_THINGS',
#    'ALEXA'],
#   'communication_protocol': ['THREAD',
#    'Z_WAVE',
#    'WIFI',
#    'ZIGBEE',
#    'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E12',
#   'energy_efficiency_class': 'E',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 25000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': 6000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'Smart Connect Bulb - Weiße Helligkeit Generation 1',
#   'brand': 'Intuit Home',
#   'price': 9.99,
#   'description': None,
#   'platforms': ['GOOGLE_HOME', 'MATTER', 'SMART_THINGS', 'IFTTT'],
#   'communication_protocol': ['Z_WAVE',
#    'WIFI',
#    'ZIGBEE',
#    'MATTER',
#    'BLUETOOTH'],
#   'light_color': 'WHITE',
#   'socket': 'E14',
#   'energy_efficiency_class': 'F',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 10000,
#   'wattage': 6,
#   'brightness': 900,
#   'color_temp': 6000},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb Generation 2 - Farbe Frei! E12',
#   'brand': 'Intuit Home',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'ALEXA', 'MATTER', 'IFTTT'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'light_color': 'RGB',
#   'socket': 'E12',
#   'energy_efficiency_class': 'F',
#   'features': 'LIGHTING_EFFECTS',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 15000,
#   'wattage': 6,
#   'brightness': 600,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartHub G9 Motion Edition',
#   'brand': 'Hometics',
#   'price': 29.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'HUBITAT',
#    'IFTTT'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'light_color': 'WHITE',
#   'socket': 'G9',
#   'energy_efficiency_class': 'B',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_ALL_FEATURES',
#   'lifetime': 20000,
#   'wattage': 12,
#   'brightness': 600,
#   'color_temp': 2700},
#  {'product_no': None,
#   'product_type': 'SmartBulb',
#   'name': 'SmartBulb CasaCore RGB E40 Motion-Sensor Edition Generation 3.0',
#   'brand': 'CasaCore',
#   'price': 8.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'MATTER',
#    'SMART_THINGS',
#    'IFTTT',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'WIFI', 'BLUETOOTH'],
#   'light_color': 'RGB',
#   'socket': 'E40',
#   'energy_efficiency_class': 'A',
#   'features': 'MOTION_SENSOR',
#   'requireshub': 'FOR_SOME_FEATURES',
#   'lifetime': 30000,
#   'wattage': 60,
#   'brightness': 500,
#   'color_temp': None},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'SmartCircle FerroSync Serie 1 - Kugeliger Thermomanager für Smart Heim',
#   'brand': 'FerroSync',
#   'price': 75.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'color': 'BLUE',
#   'shape': 'CIRCLE',
#   'features': ['LOCAL_ONLY',
#    'AIR_QUALITY_SENSOR',
#    'PHYSICAL_BUTTONS',
#    'PHYSICAL_DIAL',
#    'USAGE_REPORTS'],
#   'cwire': 'ADAPTER_INCLUDED',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'IntelliThermostat PRO Circle Edition',
#   'brand': 'Orbital Home',
#   'price': 80.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'HUBITAT'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'BLUE',
#   'shape': 'CIRCLE',
#   'features': ['AIR_QUALITY_SENSOR',
#    'TOUCH_SCREEN',
#    'USAGE_REPORTS',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X4'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'FerroSync Connect Gen. 1 Smart Thermostat',
#   'brand': 'FerroSync',
#   'price': 75.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'GOOGLE_HOME', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI'],
#   'color': 'BLACK',
#   'shape': 'RECTANGLE',
#   'features': ['LOCAL_ONLY'],
#   'cwire': 'ADAPTER_INCLUDED',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X2'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'FerroSync SyncMaster Gen 4 Pro Smart Black Edition',
#   'brand': 'FerroSync',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'GOOGLE_HOME', 'MATTER', 'SMART_THINGS'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'BLACK',
#   'shape': 'RECTANGLE',
#   'features': ['GEOFENCING',
#    'PHYSICAL_BUTTONS',
#    'LOCAL_ONLY',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'ADAPTER_INCLUDED',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'SmartCircle Thermostat - CasaCore Generation 1',
#   'brand': 'CasaCore',
#   'price': 250.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'SILVER',
#   'shape': 'CIRCLE',
#   'features': ['LOCAL_ONLY',
#    'GEOFENCING',
#    'AIR_QUALITY_SENSOR',
#    'TOUCH_SCREEN',
#    'PHYSICAL_BUTTONS',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'FerroSync SyncMaster Generation 1',
#   'brand': 'FerroSync',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'HUBITAT'],
#   'communication_protocol': ['THREAD', 'MATTER', 'WIFI', 'BLUETOOTH'],
#   'color': 'WHITE',
#   'shape': 'RECTANGLE',
#   'features': ['OPEN_API',
#    'TOUCH_SCREEN',
#    'USAGE_REPORTS',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'AVAILABLE_AS_ADD_ON',
#   'replaceable_batteries': 'AA_X4'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'Intuit SmartPro 2 - Komfort und Luftqualität in blauer Eleganz',
#   'brand': 'Intuit Home',
#   'price': 250.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'color': 'BLUE',
#   'shape': 'RECTANGLE',
#   'features': ['AIR_QUALITY_SENSOR',
#    'PHYSICAL_BUTTONS',
#    'TOUCH_SCREEN',
#    'LOCAL_ONLY'],
#   'cwire': 'REQUIRES_C_WIRE_OR_ADAPTER',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'SmartHome Manager S1 Gen 1 Pro',
#   'brand': 'Hometics',
#   'price': 99.99,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'HUBITAT',
#    'IFTTT',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD',
#    'Z_WAVE',
#    'WIFI',
#    'ZIGBEE',
#    'MATTER',
#    'BLUETOOTH'],
#   'color': 'SILVER',
#   'shape': 'OVAL',
#   'features': ['TOUCH_SCREEN', 'USAGE_REPORTS', 'ENERGY_SAVING_TIPS'],
#   'cwire': 'REQUIRES_C_WIRE_OR_ADAPTER',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X2'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'FerroSync Air Quality Smart Thermostat Gen1',
#   'brand': 'FerroSync',
#   'price': 75.0,
#   'description': None,
#   'platforms': ['ALEXA', 'MATTER', 'IFTTT'],
#   'communication_protocol': ['ZIGBEE', 'Z_WAVE', 'WIFI'],
#   'color': 'SILVER',
#   'shape': 'RECTANGLE',
#   'features': ['AIR_QUALITY_SENSOR', 'TOUCH_SCREEN', 'LOCAL_ONLY'],
#   'cwire': 'NOT_REQUIRED',
#   'remote_temperature_sensor': 'NOT_AVAILABLE',
#   'replaceable_batteries': 'AA_X2'},
#  {'product_no': None,
#   'product_type': 'SmartThermostat',
#   'name': 'SmartThermostat X - Weiß Edition V2',
#   'brand': 'Hometics',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HOME_ASSISTANT', 'GOOGLE_HOME', 'IFTTT'],
#   'communication_protocol': ['WIFI', 'BLUETOOTH'],
#   'color': 'WHITE',
#   'shape': 'RECTANGLE',
#   'features': ['AIR_QUALITY_SENSOR',
#    'TOUCH_SCREEN',
#    'PHYSICAL_DIAL',
#    'ENERGY_SAVING_TIPS'],
#   'cwire': 'REQUIRES_C_WIRE_OR_ADAPTER',
#   'remote_temperature_sensor': 'INCLUDED',
#   'replaceable_batteries': 'AAA_X3'},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'Core Connect Hub 3.0 Advanced Edition',
#   'brand': 'CasaCore',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'MATTER', 'HUBITAT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['Z_WAVE', 'MATTER', 'WIFI'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'SmartHub Home - Generation 1 Pro',
#   'brand': 'Intuit Home',
#   'price': 230.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT',
#    'APPLE_HOME_KIT',
#    'MATTER',
#    'IFTTT',
#    'ALEXA'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'BLUETOOTH'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'Intuit Home SmartHub X1 Revolution Edition',
#   'brand': 'Intuit Home',
#   'price': 55.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'BLUETOOTH'],
#   'features': ['SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'FerroSync SmartHub - Generation 1 Universal',
#   'brand': 'FerroSync',
#   'price': 155.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT', 'HUBITAT', 'IFTTT', 'SMART_THINGS', 'ALEXA'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'Connectiv Hub 1.0 Series',
#   'brand': 'Hometics',
#   'price': 155.0,
#   'description': None,
#   'platforms': ['ALEXA', 'APPLE_HOME_KIT', 'HUBITAT'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'WIFI'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'Orbital Connect Hub 3.0 - Generation Apex',
#   'brand': 'Orbital Home',
#   'price': 55.0,
#   'description': None,
#   'platforms': ['ALEXA', 'HOME_ASSISTANT', 'GOOGLE_HOME', 'SMART_THINGS'],
#   'communication_protocol': ['THREAD', 'ZIGBEE'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'SmartConnect Hub Generation 1',
#   'brand': 'Hometics',
#   'price': 190.0,
#   'description': None,
#   'platforms': ['HOME_ASSISTANT', 'HUBITAT', 'IFTTT', 'ALEXA', 'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'Z_WAVE', 'MATTER', 'BLUETOOTH'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'SmartConnect X2: Revolutionäre Hub-Generation für die Zukunft des Smart Homes',
#   'brand': 'Orbital Home',
#   'price': 155.0,
#   'description': None,
#   'platforms': ['ALEXA', 'GOOGLE_HOME', 'HUBITAT', 'SMART_THINGS'],
#   'communication_protocol': ['Z_WAVE', 'BLUETOOTH'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'CasaCore Connect Hub Gen 1 SmartHub Edition',
#   'brand': 'CasaCore',
#   'price': 190.0,
#   'description': None,
#   'platforms': ['GOOGLE_HOME', 'MATTER', 'SMART_THINGS'],
#   'communication_protocol': ['Z_WAVE', 'BLUETOOTH'],
#   'features': ['SPEAKER', 'SCREEN']},
#  {'product_no': None,
#   'product_type': 'SmartHub',
#   'name': 'SmartConnect Hub Generation 1',
#   'brand': 'Intuit Home',
#   'price': 100.0,
#   'description': None,
#   'platforms': ['APPLE_HOME_KIT',
#    'MATTER',
#    'IFTTT',
#    'SMART_THINGS',
#    'ALEXA',
#    'GOOGLE_HOME'],
#   'communication_protocol': ['THREAD', 'ZIGBEE', 'MATTER', 'WIFI'],
#   'features': ['SPEAKER']},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'FerroSync FerroSync Generation 6.2 - Sauber mit Intelligenz',
#   'brand': 'FerroSync',
#   'price': 600.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['LI_DAR',
#    'SELF_CLEANING_BRUSH_ROLL',
#    'MOP',
#    'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'IntelliClean Pro X6000 Smart Edition 6K',
#   'brand': 'FerroSync',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['LI_DAR', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'Intuit Home Vacuum Robot Generation X3 - Saugroboter mit Navigation & Selbstreinigung',
#   'brand': 'Intuit Home',
#   'price': 300.0,
#   'description': None,
#   'suction_strength': 3000,
#   'hardware_features': ['LI_DAR', 'MOP', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING', 'OBSTACLE_AVOIDANCE'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'PowerClean X3 MOP Edition',
#   'brand': 'Intuit Home',
#   'price': 300.0,
#   'description': None,
#   'suction_strength': 3000,
#   'hardware_features': ['MOP'],
#   'software_features': ['HOME_MAPPING',
#    'SPECIFY_CLEANING_ZONES',
#    'OBSTACLE_AVOIDANCE'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'CasaCore Pro S - PowerCleaner 3.0 Edition',
#   'brand': 'CasaCore',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 3000,
#   'hardware_features': ['MOP', 'SIDE_BRUSHES', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING', 'SPECIFY_CLEANING_ZONES'],
#   'dock': 'DOCK_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'SmartClean M6 Plus Power Edition',
#   'brand': 'Hometics',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['MOP', 'SIDE_BRUSHES', 'SELF_CLEANING_BRUSH_ROLL'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'FerroSync MJ Pro XXL - Saphir Edition',
#   'brand': 'FerroSync',
#   'price': 500.0,
#   'description': None,
#   'suction_strength': 2000,
#   'hardware_features': ['LI_DAR', 'SIDE_BRUSHES', 'SELF_CLEANING_MOP'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NO_DOCK'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'IntelliClean Pro Gen2 PowerVac',
#   'brand': 'Orbital Home',
#   'price': 400.0,
#   'description': None,
#   'suction_strength': 5300,
#   'hardware_features': ['SIDE_BRUSHES'],
#   'software_features': ['OBSTACLE_AVOIDANCE'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'CasaCore Roboter 6000 - Selbstfahrendes Reinigungs-Genie mit selbstreinender Mop und intelligentem Navigationssystem. Edition X.',
#   'brand': 'CasaCore',
#   'price': 500.0,
#   'description': None,
#   'suction_strength': 6000,
#   'hardware_features': ['SELF_CLEANING_MOP',
#    'SIDE_BRUSHES',
#    'SELF_CLEANING_BRUSH_ROLL'],
#   'software_features': ['SPECIFY_CLEANING_ZONES', 'OBSTACLE_AVOIDANCE'],
#   'dock': 'DOCK_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'VacuumRobot',
#   'name': 'PowerSweep Pro X2 - Sauberkeit auf höchstem Niveau',
#   'brand': 'CasaCore',
#   'price': 600.0,
#   'description': None,
#   'suction_strength': 5300,
#   'hardware_features': ['LI_DAR', 'MOP', 'SIDE_BRUSHES'],
#   'software_features': ['HOME_MAPPING'],
#   'dock': 'NOT_INCLUDED'},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': '"DwarfPower XL Max 400"',
#   'brand': 'Yellow Dwarf Power',
#   'price': 67.2,
#   'description': None,
#   'length': 1400,
#   'height': 1000,
#   'width': 30,
#   'max_power_output': 400,
#   'weight': 29.4},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'EnergieMaxx X40 Plus - SolarEdge XL',
#   'brand': 'SolarTuitive',
#   'price': 67.2,
#   'description': None,
#   'length': 1400,
#   'height': 1000,
#   'width': 50,
#   'max_power_output': 400,
#   'weight': 28.0},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'SolarTuitive ST-GenX 1950 Max Power',
#   'brand': 'SolarTuitive',
#   'price': 223.76,
#   'description': None,
#   'length': 1950,
#   'height': 1500,
#   'width': 50,
#   'max_power_output': 450,
#   'weight': 61.42},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'SmartPanel Evolution S12V',
#   'brand': 'SolarTuitive',
#   'price': 24.48,
#   'description': None,
#   'length': 1700,
#   'height': 1200,
#   'width': 40,
#   'max_power_output': 100,
#   'weight': 46.92},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'SolarPowerMax Aurora Serie Generation 1 - 450 Watt Premium Panel',
#   'brand': 'Aurora Panel',
#   'price': 195.08,
#   'description': None,
#   'length': 1700,
#   'height': 1500,
#   'width': 40,
#   'max_power_output': 450,
#   'weight': 61.2},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'Effizienz XL - Generation XD',
#   'brand': 'Yellow Dwarf Power',
#   'price': 105.3,
#   'description': None,
#   'length': 1950,
#   'height': 1500,
#   'width': 50,
#   'max_power_output': 300,
#   'weight': 64.35},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'EffizienzMaster X3 - Solar-Panel Gen. 2023',
#   'brand': 'SolarTuitive',
#   'price': 131.62,
#   'description': None,
#   'length': 1950,
#   'height': 1500,
#   'width': 50,
#   'max_power_output': 300,
#   'weight': 52.65},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'X300 Solarpower Max',
#   'brand': 'Yellow Dwarf Power',
#   'price': 138.72,
#   'description': None,
#   'length': 1700,
#   'height': 1200,
#   'width': 30,
#   'max_power_output': 400,
#   'weight': 34.68},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'Effiziente SolarPanels von Yellow Dwarf Power - Generation X',
#   'brand': 'Yellow Dwarf Power',
#   'price': 30.6,
#   'description': None,
#   'length': 1700,
#   'height': 1500,
#   'width': 30,
#   'max_power_output': 100,
#   'weight': 51.0},
#  {'product_no': None,
#   'product_type': 'SolarPanel',
#   'name': 'EcoMax X300 - Leistungsfähig und Einfach',
#   'brand': 'Aurora Panel',
#   'price': 20.4,
#   'description': None,
#   'length': 1700,
#   'height': 1000,
#   'width': 50,
#   'max_power_output': 100,
#   'weight': 30.6}]

# %%
from langchain.prompts import PromptTemplate

prompt_template = PromptTemplate(
    input_variables=["json_data"],
    template="""
    Du bist ein KI-Modell für Produkttextgenerierung. Deine Aufgabe ist es auf Grundlage übergebener Werte Texte zu erzeugen, die ein Produkt auf basis des gegebenen JSON Objects beschreiben.
    Gebe nur den Text aus ohne weiteren Kommentar. Erstelle einen Fließtext ohne sich wiederholende Phrasen. 

    Basierend auf den folgenden Werten, schreibe einen Text:
    {json_data}
    """
)

chain = prompt_template | llm

for idx, product in enumerate(products):
    chunks = []
    for chunk in chain.stream({"json_data": json.dumps(product)}):
        chunks.append(chunk)
    products[idx]["description"] = "".join(chunks)
